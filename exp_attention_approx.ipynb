# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# dl kaggle data - https://www.kaggle.com/datasets/dhruvildave/en-fr-translation-dataset?select=en-fr.csv

import os
import kagglehub

dir = kagglehub.dataset_download("dhruvildave/en-fr-translation-dataset")
filename = 'en-fr.csv'
filepath = os.path.join(dir, filename)

# %%
import torch

# set the seed for reproducibility
torch.manual_seed(12)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(12)

# %%
# extract data and construct Q, K, V vectors

import pandas as pd
import torch
from typing import Tuple, List
from transformers import AutoTokenizer


CSV_PATH = filepath
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# pre-trained tokenizer
N = 2048
TOKENIZER = AutoTokenizer.from_pretrained("t5-small", model_max_length=N)


# extract the raw data and structure Q, K, V, Y_true tensors
def extract_data(
        batch_size: int,
        seq_len: int,
        d_model: int,
        device: torch.device = DEVICE,
        csv_path: str = CSV_PATH
    ) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]: # q, k, v, y_true

    chunk_iterator = pd.read_csv(
        csv_path, 
        chunksize=batch_size * 2,
        header=None, # ignore file header
        names=['en', 'fr'],
        usecols=['en', 'fr'], 
        on_bad_lines='skip'
    )
    first_chunk = next(chunk_iterator)

    # tokenization and padding for input data (en)
    raw_english_sentences: List[str] = first_chunk['en'].astype(str).tolist()[:batch_size]
    tokenized_inputs = TOKENIZER(raw_english_sentences, padding='max_length', truncation=True, max_length=seq_len, return_tensors='pt')
    
    # tokenization and padding for the target data (fr)
    raw_french_sentences: List[str] = first_chunk['fr'].astype(str).tolist()[:batch_size]
    tokenized_targets = TOKENIZER(raw_french_sentences, padding='max_length', truncation=True, max_length=seq_len, return_tensors='pt')
    
    # total tokens 
    N_tokens = tokenized_inputs['input_ids'].shape[1]
    
    # simulate Q, K, V vectors (used by the encoder)
    Q = torch.randn(batch_size, N_tokens, d_model, device=device)
    K = torch.randn(batch_size, N_tokens, d_model, device=device)
    V = torch.randn(batch_size, N_tokens, d_model, device=device)
    
    # true fr target token ids to compute loss
    Y_true = tokenized_targets['input_ids'].to(device)
    
    return Q, K, V, Y_true


# extract train and test data with different sequence length
N_TEST = 4096
D_MODEL = 512
BATCH_SIZE = 4
CSV_PATH = filepath

Q_base, K_base, V_base, Y_true_base = extract_data(BATCH_SIZE, N, D_MODEL, DEVICE)
Q_test, K_test, V_test, Y_true_test = extract_data(BATCH_SIZE, N_TEST, D_MODEL, DEVICE)

# %%
# define attention layers 

import torch
import torch.nn as nn
import torch.nn.functional as f

# standard mha (o(n^2))
class StandardMHA(nn.Module):
    def __init__(self, d_k: int):
        super().__init__()
        self.scaling_factor = 1 / (d_k ** 0.5)

    def forward(self, Q: torch.Tensor, K: torch.Tensor, V: torch.Tensor) -> torch.Tensor:
        S = torch.matmul(Q, K.transpose(-2, -1)) * self.scaling_factor # scaled score s
        A = torch.softmax(S, dim=-1) # attention vector a
        Z = torch.matmul(A, V) # context vector z - [b, n, d]
        return Z
    

# linformer (o(nl))
class Linformer(nn.Module):
    def __init__(self, N_max: int, L: int, d_k: int):
        super().__init__()
        # use n_max (which is n from global) to size the projection matrix
        self.E = nn.Parameter(torch.randn(N_max, L, device=DEVICE), requires_grad=True) # projection vector (learned parameter unique to linformer)
        self.scaling_factor = 1 / (d_k ** 0.5)

    def forward(self, Q: torch.Tensor, K: torch.Tensor, V: torch.Tensor) -> torch.Tensor:
        N_curr = K.shape[1]
        
        # fix: allow the projection matrix to handle sequences up to its max size (n)
        if N_curr > self.E.shape[0]:
             raise RuntimeError(f"... linformer: sequence length {N_curr} exceeds fixed projection size {self.E.shape[0]}. failed to generalize ...")
        
        # limited elements l (use the necessary part of the learned projection)
        L_proj = self.E[:N_curr, :] # use l_proj to avoid name conflict with l in self.e

        # compress key and value vectors using l
        K_compressed = torch.matmul(K.transpose(-2, -1), L_proj).transpose(-2, -1)
        V_compressed = torch.matmul(V.transpose(-2, -1), L_proj).transpose(-2, -1)
        
        # compute context vector z
        S = torch.matmul(Q, K_compressed.transpose(-2, -1)) * self.scaling_factor
        A = torch.softmax(S, dim=-1) 
        Z = torch.matmul(A, V_compressed)
        return Z


# performer (o(n))
class Performer(nn.Module):
    def __init__(self, d_model: int, m_features: int):
        super().__init__()
        self.m = m_features
        self.d_model = d_model
        # random features normalized by 1/sqrt(m)
        self.random_features = nn.Parameter(torch.randn(d_model, m_features, device=DEVICE) / (m_features ** 0.5), requires_grad=False) # fixed random features
        
    def forward(self, Q: torch.Tensor, K: torch.Tensor, V: torch.Tensor) -> torch.Tensor:
        # simplified rfa approximation: exp(q' * k') * v / exp(q' * sum(k'))
        
        # apply elu + 1 to the feature map for positive approximation of exp(x)
        Q_prime = f.elu(torch.matmul(Q, self.random_features)) + 1
        K_prime = f.elu(torch.matmul(K, self.random_features)) + 1
        
        # term 1: k_prime.t @ v -> [b, m, d_model]  - numerator: q_prime @ term 1 -> [b, n, d_model]
        numerator_term_1 = torch.matmul(K_prime.transpose(-2, -1), V)
        numerator = torch.matmul(Q_prime, numerator_term_1)
        
        # denominator term 1: sum(k_prime) -> [b, 1, m]
        denominator_term_1 = torch.sum(K_prime, dim=1).unsqueeze(1)
        denominator = torch.matmul(Q_prime, denominator_term_1.transpose(-2, -1)) 
        
        epsilon = 1e-6 # increased epsilon slightly for stability
        Z = numerator / (denominator + epsilon)
        return Z
    

# longformer (o(nw))
class Longformer(nn.Module):
    def __init__(self, window_size: int, d_k: int):
        super().__init__()
        self.w = window_size
        self.scaling_factor = 1 / (d_k ** 0.5)
        self.neg_inf = -1e9

    def _create_local_mask(self, N_curr: int, device: torch.device) -> torch.Tensor:
        indices = torch.arange(N_curr, device=device).unsqueeze(-1)
        diff_matrix = torch.abs(indices - indices.transpose(0, 1))
        mask = (diff_matrix <= self.w)
        return mask.bool()

    def forward(self, Q: torch.Tensor, K: torch.Tensor, V: torch.Tensor) -> torch.Tensor:
        B, N_curr, _ = Q.shape

        S = torch.matmul(Q, K.transpose(-2, -1)) * self.scaling_factor # attention scores 

        # create and apply a mask m
        local_mask = self._create_local_mask(N_curr, Q.device)
        M = local_mask.unsqueeze(0).expand(B, -1, -1)
        masked_scores = S.masked_fill(~M, self.neg_inf)

        # compute z
        A = torch.softmax(masked_scores, dim=-1)
        Z = torch.matmul(A, V)
        return Z

# %%
# standard encoder layer w/ attention module
class EncoderLayer(nn.Module):
    def __init__(self, attention_module: nn.Module, d_model: int):
        super().__init__()
        self.attn = attention_module # takes one of the four attention classes
        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_model * 4),
            nn.ReLU(),
            nn.Linear(d_model * 4, d_model)
        )
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # attention block
        norm_x = self.norm1(x)

        # encoder has the same q, k, v (norm_x, norm_x, norm_x)
        attn_out = self.attn(norm_x, norm_x, norm_x)
        x = x + self.dropout1(attn_out) # residual connection

        # feed-forward block
        norm_x = self.norm2(x)
        ffn_out = self.ffn(norm_x)
        output = x + self.dropout2(ffn_out) # residual connection
        return output


# standard decoder layer
class DecoderLayer(nn.Module):
    def __init__(self, attention_module: nn.Module, d_model: int):
        super().__init__()
        # decoder self-attention (same type as encoder for this simulation)
        self.self_attn = attention_module 
        # encoder-decoder attention
        self.cross_attn = StandardMHA(d_model) # apply standardmha
        
        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_model * 4),
            nn.ReLU(),
            nn.Linear(d_model * 4, d_model)
        )
        
        self.norm1 = nn.LayerNorm(d_model) # self-attn norm
        self.norm2 = nn.LayerNorm(d_model) # cross-attn norm
        self.norm3 = nn.LayerNorm(d_model) # ffn norm
        self.dropout1 = nn.Dropout(0.1)
        self.dropout2 = nn.Dropout(0.1)
        self.dropout3 = nn.Dropout(0.1)

    # takes the decoder input (tgt) and the encoder output (mem)
    def forward(self, tgt: torch.Tensor, mem: torch.Tensor) -> torch.Tensor:     
        # masked decoder self-attention (q = k = v = tgt)
        norm_tgt = self.norm1(tgt)
        self_attn_out = self.self_attn(norm_tgt, norm_tgt, norm_tgt) 
        tgt = tgt + self.dropout1(self_attn_out) # residual connection

        # encoder-decoder cross-attention (q = tgt, k = v = mem)
        norm_tgt = self.norm2(tgt)
        cross_attn_out = self.cross_attn(norm_tgt, mem, mem) 
        tgt = tgt + self.dropout2(cross_attn_out) # residual connection

        # feed-forward block
        norm_tgt = self.norm3(tgt)
        ffn_out = self.ffn(norm_tgt)
        output = tgt + self.dropout3(ffn_out) # residual connection
        return output


# full model
class TransformerSeq2Seq(nn.Module):
    def __init__(self, attention_module: nn.Module, d_model: int, vocab_size: int, pad_token_id: int):
        super().__init__()
        # encoder layer
        self.encoder = EncoderLayer(attention_module, d_model)

        # decoder layer
        self.decoder = DecoderLayer(attention_module, d_model)
        
        # target token embedding
        self.target_embedding = nn.Embedding(vocab_size, d_model)
        
        # final linear/softmax head for logits
        self.linear_head = nn.Linear(d_model, vocab_size)

        # store pad id for mask generation
        self.pad_token_id = pad_token_id


    def forward(self, Q, K, V, Y_true):
        # encoder (q, k, v are used in the encoder layer to create encoded memory)
        mem = self.encoder(Q)
        # the decoder input is the true target tokens shifted right
        tgt_input_tokens = Y_true[:, :-1]
        tgt = self.target_embedding(tgt_input_tokens)
        decoder_output = self.decoder(tgt, mem)
        logits = self.linear_head(decoder_output)
        return logits

# %%
from transformers import AutoTokenizer


# pre-trained tokenizer
TOKENIZER = AutoTokenizer.from_pretrained("t5-small", model_max_length=N)
VOCAB_SIZE = TOKENIZER.vocab_size


# full seq2seq transformers using diff attention mechanisms
class TransformerStandard(TransformerSeq2Seq):
    def __init__(self, d_model: int, vocab_size: int):
        attn = StandardMHA(d_model)
        pad_id = TOKENIZER.pad_token_id
        super().__init__(attn, d_model, vocab_size, pad_token_id=pad_id)


class TransformerLinformer(TransformerSeq2Seq):
    def __init__(self, N_max: int, L: int, D_MODEL: int, vocab_size: int):
        attn = Linformer(N_max, L, D_MODEL)
        pad_id = TOKENIZER.pad_token_id
        super().__init__(attn, D_MODEL, vocab_size, pad_token_id=pad_id)


class TransformerPerformer(TransformerSeq2Seq):
    def __init__(self, D_MODEL: int, m_PERFORMER: int, vocab_size: int):
        attn = Performer(D_MODEL, m_PERFORMER)
        pad_id = TOKENIZER.pad_token_id
        super().__init__(attn, D_MODEL, vocab_size, pad_token_id=pad_id)

class TransformerLongformer(TransformerSeq2Seq):
    def __init__(self, w_LONGFORMER: int, D_MODEL: int, vocab_size: int):
        attn = Longformer(w_LONGFORMER, D_MODEL)
        pad_id = TOKENIZER.pad_token_id
        super().__init__(attn, D_MODEL, vocab_size, pad_token_id=pad_id)



# instantiate full seq2seq transformer models

D_MODEL = 512
L_LINFORMER = 128   # linformer compressed sequence length L << N
m_PERFORMER = 256   # performer number of random features m < D
w_LONGFORMER = 128  # longformer local window size w << N

models = {
    '1. Standard MHA': TransformerStandard(D_MODEL, VOCAB_SIZE).to(DEVICE),
    '2. Linformer': TransformerLinformer(Q_base.shape[1], L_LINFORMER, D_MODEL, VOCAB_SIZE).to(DEVICE), 
    '3. Performer': TransformerPerformer(D_MODEL, m_PERFORMER, VOCAB_SIZE).to(DEVICE),
    '4. LongFormer': TransformerLongformer(w_LONGFORMER, D_MODEL, VOCAB_SIZE).to(DEVICE),
}

# %%
# training

EPOCHS = 3000
LEARNING_RATE = 1e-5


# early stopping 
class EarlyStopper:
    # increased patience for distillation
    def __init__(self, patience: int = 20, min_delta: float = 1e-10, is_distillation: bool = False):
        self.patience = patience * 5 if is_distillation else patience # increased patience for kd
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, validation_loss: float) -> bool:
        if validation_loss < self.min_validation_loss - self.min_delta:
            self.min_validation_loss = validation_loss
            self.counter = 0
        
        elif validation_loss > self.min_validation_loss + self.min_delta:
            self.counter += 1
            if self.counter >= self.patience: return True

        return False


# training standard mha
def train(
        model: nn.Module,
        Q: torch.Tensor,
        K: torch.Tensor,
        V: torch.Tensor,
        Y_true: torch.Tensor,
        num_steps: int = EPOCHS,
        lr: float = LEARNING_RATE
        ) -> torch.Tensor:
    
    print(f"... training standard mha for stabilization ...")
    
    # target - the model's own random initial output logits
    model.eval()
    with torch.no_grad():
        init_output = model(Q, K, V, Y_true).detach()

    # optimize params
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        
    # loss & early stop
    criterion = nn.CrossEntropyLoss(ignore_index=TOKENIZER.pad_token_id)

    # training mode
    model.train()
    Y_target = Y_true[:, 1:].flatten()
    # teacher target labels for mse/ce-proxy stabilization
    target = init_output.view(-1, init_output.shape[-1]).detach()
    
    # use default patience for stabilization
    early_stopper = EarlyStopper(patience=20)
    
    # training epochs
    for step in range(num_steps):
        optimizer.zero_grad()
        output_logits = model(Q, K, V, Y_true)
        output_for_loss = output_logits.view(-1, output_logits.shape[-1]) # teshape output_logits to [b*n_tokens, vocab_size]
        
        # stabilization loss (mse proxy used originally, kept here for consistency with original logic)
        loss = f.mse_loss(output_for_loss, target) # changed to f.mse_loss for clarity
        loss.backward() 
        optimizer.step()
        
        # calculate the true language loss for reporting and early stopping
        with torch.no_grad():
            true_loss = criterion(output_for_loss, Y_target) 
            
        if (step + 1) % 10 == 0:
            print(f"... step {step + 1}/{num_steps}, stabilization loss (mse-proxy): {loss.item():.6f}, true ce loss: {true_loss.item():.6f}")

        # early stop
        if early_stopper.early_stop(true_loss.item()):
            print(f"... early stopping triggered at step {step + 1}. no improvement in true ce loss for {early_stopper.patience} steps.")
            break
    
    model.eval()
    print("  stabilization finished")
    # return the trained output logits (used as the stable distillation target)
    with torch.no_grad():
        return model(Q, K, V, Y_true)
    


# train the standard mha to get stable targets
standard_output_target_logits = train(
    models['1. Standard MHA'], Q_base, K_base, V_base, Y_true_base
)


# get the test target logits from the trained mha
with torch.no_grad():
    standard_output_test_target_logits = models['1. Standard MHA'](Q_test, K_test, V_test, Y_true_test)
# Out:
# ... training standard mha for stabilization ...
# ... step 10/3000, stabilization loss (mse-proxy): 0.051628, true ce loss: 11.597017
# ... step 20/3000, stabilization loss (mse-proxy): 0.050646, true ce loss: 11.543389
# ... step 30/3000, stabilization loss (mse-proxy): 0.050283, true ce loss: 11.576612
# ... step 40/3000, stabilization loss (mse-proxy): 0.049278, true ce loss: 11.580322
# ... step 50/3000, stabilization loss (mse-proxy): 0.048909, true ce loss: 11.568735
# ... early stopping triggered at step 59. no improvement in true ce loss for 20 steps.
#   stabilization finished

# %%
import torch

# kd for the attention approx models
EPOCHS = 3000
LEARNING_RATE = 1e-5
DISTILLATION_TEMP = 3.0 # temperature for distillation
ALPHA = 0.5

def run_distillation_simulation(
        model: nn.Module,
        Q: torch.Tensor,
        K: torch.Tensor,
        V: torch.Tensor,
        Y_true: torch.Tensor,
        target_model_name: str,
        stable_target_logits: torch.Tensor,
        num_steps: int = EPOCHS,
        lr: float = LEARNING_RATE):
 
    print(f"\n... training {target_model_name} (runs distillation) ...")
    
    # define optimizer and loss
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # loss functions
    ce_loss = nn.CrossEntropyLoss(ignore_index=TOKENIZER.pad_token_id)
    
    # set training mode
    model.train()

    # reshape target for cross-entropy loss (hard labels)
    Y_target = Y_true[:, 1:].flatten()
    
    # reshape stable_target_logits (teacher's output)
    stable_target_for_loss = stable_target_logits.view(-1, stable_target_logits.shape[-1]).detach()

    # early stopper (uses increased patience)
    early_stopper = EarlyStopper(is_distillation=True)
    
    # a utility function for kl-divergence on soft targets (kd loss)
    def distillation_loss(student_logits, teacher_logits, temperature, alpha, true_labels):
        # soft targets
        student_log_softmax = f.log_softmax(student_logits / temperature, dim=-1)
        teacher_softmax = f.softmax(teacher_logits / temperature, dim=-1)
        
        # kl divergence loss
        kd_loss = f.kl_div(student_log_softmax, teacher_softmax, reduction='batchmean') * (temperature ** 2)
        
        # hard targets - standard cross entropy loss on true labels
        hard_loss = ce_loss(student_logits, true_labels)
        
        # combined loss
        return alpha * hard_loss + (1.0 - alpha) * kd_loss

    for step in range(num_steps):
        optimizer.zero_grad()
        output_logits = model(Q, K, V, Y_true)
        output_for_loss = output_logits.view(-1, output_logits.shape[-1])   
        
        # combined distillation loss (kl + ce)
        loss = distillation_loss(
            student_logits=output_for_loss, 
            teacher_logits=stable_target_for_loss, 
            temperature=DISTILLATION_TEMP, 
            alpha=ALPHA, 
            true_labels=Y_target
        )
        
        loss.backward()
        optimizer.step()
        
        # calculate the true language loss for reporting and early stopping
        with torch.no_grad():
            # use the standard ce loss for the true performance metric
            true_loss = ce_loss(output_for_loss, Y_target)
            
        if (step + 1) % 10 == 0:
            # print the actual distillation loss and the true ce loss
            print(f"... step {step + 1}/{num_steps}, distillation loss (kl+ce): {loss.item():.6f}, true ce loss: {true_loss.item():.6f}")

        if early_stopper.early_stop(true_loss.item()):
            print(f"... early stopping triggered at step {step + 1}. no improvement in true ce loss for {early_stopper.patience} steps.")
            break
    model.eval()
    print("  distillation simulation finished.")


# loop the rest of the models
for name, model in models.items():
    if name != '1. Standard MHA':
        run_distillation_simulation(
            model=model,
            Q=Q_base,
            K=K_base,
            V=V_base,
            Y_true=Y_true_base,
            target_model_name=name, 
            stable_target_logits=standard_output_target_logits,
            num_steps=EPOCHS,
        )
    
    # ensure inputs are detached for timing and evaluation
    Q_base.requires_grad_(False); K_base.requires_grad_(False); V_base.requires_grad_(False)
    Q_test.requires_grad_(False); K_test.requires_grad_(False); V_test.requires_grad_(False)
    Y_true_base.requires_grad_(False); Y_true_test.requires_grad_(False)
# Out:
# ... training 2. Linformer (runs distillation) ...
# ... step 10/3000, distillation loss (kl+ce): 587.602234, true ce loss: 228.881927
# ... step 20/3000, distillation loss (kl+ce): 566.299072, true ce loss: 223.275284
# ... step 30/3000, distillation loss (kl+ce): 552.684387, true ce loss: 214.428635
# ... step 40/3000, distillation loss (kl+ce): 531.806763, true ce loss: 213.445389
# ... step 50/3000, distillation loss (kl+ce): 503.146179, true ce loss: 198.092361
# ... step 60/3000, distillation loss (kl+ce): 491.892792, true ce loss: 194.425674
# ... step 70/3000, distillation loss (kl+ce): 475.524353, true ce loss: 195.177338
# ... step 80/3000, distillation loss (kl+ce): 453.062012, true ce loss: 185.368027
# ... step 90/3000, distillation loss (kl+ce): 432.694794, true ce loss: 173.630569
# ... step 100/3000, distillation loss (kl+ce): 416.769165, true ce loss: 168.873611
# ... step 110/3000, distillation loss (kl+ce): 401.351257, true ce loss: 160.482758
# ... step 120/3000, distillation loss (kl+ce): 391.480194, true ce loss: 169.633072
# ... step 130/3000, distillation loss (kl+ce): 372.212463, true ce loss: 153.534210
# ... step 140/3000, distillation loss (kl+ce): 366.110840, true ce loss: 160.081543
# ... step 150/3000, distillation loss (kl+ce): 346.054535, true ce loss: 146.748230
# ... step 160/3000, distillation loss (kl+ce): 336.895569, true ce loss: 143.389359
# ... step 170/3000, distillation loss (kl+ce): 324.741211, true ce loss: 133.618027
# ... step 180/3000, distillation loss (kl+ce): 316.159760, true ce loss: 131.770554
# ... step 190/3000, distillation loss (kl+ce): 304.144135, true ce loss: 127.256584
# ... step 200/3000, distillation loss (kl+ce): 291.824402, true ce loss: 125.226357
# ... step 210/3000, distillation loss (kl+ce): 284.520691, true ce loss: 122.706963
# ... step 220/3000, distillation loss (kl+ce): 274.999298, true ce loss: 115.495262
# ... step 230/3000, distillation loss (kl+ce): 271.666962, true ce loss: 120.361496
# ... step 240/3000, distillation loss (kl+ce): 258.891968, true ce loss: 108.818153
# ... step 250/3000, distillation loss (kl+ce): 256.117004, true ce loss: 109.600906
# ... step 260/3000, distillation loss (kl+ce): 244.866882, true ce loss: 102.158081
# ... step 270/3000, distillation loss (kl+ce): 244.139832, true ce loss: 105.028503
# ... step 280/3000, distillation loss (kl+ce): 233.972809, true ce loss: 93.172722
# ... step 290/3000, distillation loss (kl+ce): 232.738968, true ce loss: 97.281960
# ... step 300/3000, distillation loss (kl+ce): 228.563446, true ce loss: 90.256378
# ... step 310/3000, distillation loss (kl+ce): 218.983246, true ce loss: 86.635086
# ... step 320/3000, distillation loss (kl+ce): 216.238525, true ce loss: 87.801918
# ... step 330/3000, distillation loss (kl+ce): 213.735382, true ce loss: 82.338516
# ... step 340/3000, distillation loss (kl+ce): 209.410629, true ce loss: 79.229942
# ... step 350/3000, distillation loss (kl+ce): 203.213013, true ce loss: 74.289780
# ... step 360/3000, distillation loss (kl+ce): 205.086975, true ce loss: 79.736221
# ... step 370/3000, distillation loss (kl+ce): 203.022919, true ce loss: 79.033432
# ... step 380/3000, distillation loss (kl+ce): 192.984955, true ce loss: 69.721764
# ... step 390/3000, distillation loss (kl+ce): 187.927597, true ce loss: 65.462959
# ... step 400/3000, distillation loss (kl+ce): 190.354340, true ce loss: 63.473717
# ... step 410/3000, distillation loss (kl+ce): 184.869064, true ce loss: 63.357758
# ... step 420/3000, distillation loss (kl+ce): 182.669601, true ce loss: 59.385841
# ... step 430/3000, distillation loss (kl+ce): 181.594208, true ce loss: 63.318047
# ... step 440/3000, distillation loss (kl+ce): 177.519470, true ce loss: 57.722431
# ... step 450/3000, distillation loss (kl+ce): 179.581390, true ce loss: 62.188702
# ... step 460/3000, distillation loss (kl+ce): 176.971649, true ce loss: 61.460541
# ... step 470/3000, distillation loss (kl+ce): 174.399323, true ce loss: 59.829445
# ... step 480/3000, distillation loss (kl+ce): 171.358322, true ce loss: 54.816658
# ... step 490/3000, distillation loss (kl+ce): 169.870163, true ce loss: 55.904076
# ... step 500/3000, distillation loss (kl+ce): 169.244400, true ce loss: 53.304390
# ... step 510/3000, distillation loss (kl+ce): 169.087326, true ce loss: 53.719490
# ... step 520/3000, distillation loss (kl+ce): 168.695206, true ce loss: 54.802883
# ... step 530/3000, distillation loss (kl+ce): 164.517548, true ce loss: 50.850136
# ... step 540/3000, distillation loss (kl+ce): 163.780396, true ce loss: 50.622829
# ... step 550/3000, distillation loss (kl+ce): 163.690308, true ce loss: 49.681625
# ... step 560/3000, distillation loss (kl+ce): 159.897217, true ce loss: 45.692158
# ... step 570/3000, distillation loss (kl+ce): 164.147690, true ce loss: 52.385700
# ... step 580/3000, distillation loss (kl+ce): 160.026794, true ce loss: 48.485794
# ... step 590/3000, distillation loss (kl+ce): 160.813171, true ce loss: 45.400139
# ... step 600/3000, distillation loss (kl+ce): 159.361023, true ce loss: 47.393173
# ... step 610/3000, distillation loss (kl+ce): 161.399902, true ce loss: 52.182819
# ... step 620/3000, distillation loss (kl+ce): 154.725433, true ce loss: 43.667374
# ... step 630/3000, distillation loss (kl+ce): 156.788116, true ce loss: 44.615967
# ... step 640/3000, distillation loss (kl+ce): 155.285675, true ce loss: 44.945095
# ... step 650/3000, distillation loss (kl+ce): 152.929260, true ce loss: 39.745663
# ... step 660/3000, distillation loss (kl+ce): 154.213898, true ce loss: 43.960274
# ... step 670/3000, distillation loss (kl+ce): 152.619354, true ce loss: 41.671963
# ... step 680/3000, distillation loss (kl+ce): 152.870789, true ce loss: 41.599232
# ... step 690/3000, distillation loss (kl+ce): 148.974976, true ce loss: 37.329956
# ... step 700/3000, distillation loss (kl+ce): 152.990341, true ce loss: 43.066750
# ... step 710/3000, distillation loss (kl+ce): 151.228973, true ce loss: 43.826248
# ... step 720/3000, distillation loss (kl+ce): 146.571350, true ce loss: 36.998486
# ... step 730/3000, distillation loss (kl+ce): 148.605835, true ce loss: 38.469463
# ... step 740/3000, distillation loss (kl+ce): 148.478302, true ce loss: 41.270733
# ... step 750/3000, distillation loss (kl+ce): 149.625473, true ce loss: 42.395760
# ... step 760/3000, distillation loss (kl+ce): 145.097443, true ce loss: 35.789032
# ... step 770/3000, distillation loss (kl+ce): 143.916122, true ce loss: 33.259560
# ... step 780/3000, distillation loss (kl+ce): 148.297195, true ce loss: 43.174908
# ... step 790/3000, distillation loss (kl+ce): 145.601242, true ce loss: 38.742229
# ... step 800/3000, distillation loss (kl+ce): 147.780334, true ce loss: 42.004890
# ... step 810/3000, distillation loss (kl+ce): 145.424316, true ce loss: 41.088505
# ... step 820/3000, distillation loss (kl+ce): 142.724838, true ce loss: 35.203194
# ... step 830/3000, distillation loss (kl+ce): 140.836334, true ce loss: 32.521507
# ... step 840/3000, distillation loss (kl+ce): 142.587936, true ce loss: 35.680504
# ... step 850/3000, distillation loss (kl+ce): 140.663239, true ce loss: 33.296513
# ... step 860/3000, distillation loss (kl+ce): 141.008362, true ce loss: 33.520008
# ... step 870/3000, distillation loss (kl+ce): 141.182877, true ce loss: 35.202934
# ... step 880/3000, distillation loss (kl+ce): 140.103958, true ce loss: 33.946678
# ... step 890/3000, distillation loss (kl+ce): 141.024384, true ce loss: 37.954037
# ... step 900/3000, distillation loss (kl+ce): 137.273834, true ce loss: 31.500816
# ... step 910/3000, distillation loss (kl+ce): 137.556061, true ce loss: 32.581924
# ... step 920/3000, distillation loss (kl+ce): 138.482132, true ce loss: 34.253338
# ... step 930/3000, distillation loss (kl+ce): 136.556427, true ce loss: 30.220480
# ... step 940/3000, distillation loss (kl+ce): 139.042938, true ce loss: 36.624737
# ... step 950/3000, distillation loss (kl+ce): 136.457764, true ce loss: 31.772242
# ... step 960/3000, distillation loss (kl+ce): 139.195892, true ce loss: 37.774841
# ... step 970/3000, distillation loss (kl+ce): 134.691650, true ce loss: 31.451517
# ... step 980/3000, distillation loss (kl+ce): 137.622864, true ce loss: 35.094402
# ... step 990/3000, distillation loss (kl+ce): 136.054184, true ce loss: 34.558743
# ... step 1000/3000, distillation loss (kl+ce): 136.591614, true ce loss: 36.110645
# ... step 1010/3000, distillation loss (kl+ce): 132.463882, true ce loss: 28.409935
# ... step 1020/3000, distillation loss (kl+ce): 134.136902, true ce loss: 33.015205
# ... step 1030/3000, distillation loss (kl+ce): 135.513138, true ce loss: 34.920181
# ... step 1040/3000, distillation loss (kl+ce): 135.266479, true ce loss: 36.832340
# ... step 1050/3000, distillation loss (kl+ce): 134.847000, true ce loss: 35.286720
# ... step 1060/3000, distillation loss (kl+ce): 133.581268, true ce loss: 33.653774
# ... step 1070/3000, distillation loss (kl+ce): 135.479523, true ce loss: 36.754990
# ... step 1080/3000, distillation loss (kl+ce): 131.298096, true ce loss: 28.954195
# ... step 1090/3000, distillation loss (kl+ce): 132.964706, true ce loss: 33.751984
# ... step 1100/3000, distillation loss (kl+ce): 132.938797, true ce loss: 32.474651
# ... step 1110/3000, distillation loss (kl+ce): 131.812637, true ce loss: 33.160347
# ... step 1120/3000, distillation loss (kl+ce): 131.661972, true ce loss: 31.758957
# ... step 1130/3000, distillation loss (kl+ce): 128.435852, true ce loss: 27.713409
# ... step 1140/3000, distillation loss (kl+ce): 130.603088, true ce loss: 31.138441
# ... step 1150/3000, distillation loss (kl+ce): 129.270447, true ce loss: 29.609602
# ... step 1160/3000, distillation loss (kl+ce): 130.167999, true ce loss: 32.227383
# ... step 1170/3000, distillation loss (kl+ce): 128.733917, true ce loss: 29.854425
# ... step 1180/3000, distillation loss (kl+ce): 128.446472, true ce loss: 29.934330
# ... early stopping triggered at step 1188. no improvement in true ce loss for 100 steps.
#   distillation simulation finished.
#
# ... training 3. Performer (runs distillation) ...
# ... step 10/3000, distillation loss (kl+ce): 5.817956, true ce loss: 10.237531
# ... step 20/3000, distillation loss (kl+ce): 5.609643, true ce loss: 9.927228
# ... step 30/3000, distillation loss (kl+ce): 5.384134, true ce loss: 9.567935
# ... step 40/3000, distillation loss (kl+ce): 5.175053, true ce loss: 9.229832
# ... step 50/3000, distillation loss (kl+ce): 4.961961, true ce loss: 8.873410
# ... step 60/3000, distillation loss (kl+ce): 4.726473, true ce loss: 8.464560
# ... step 70/3000, distillation loss (kl+ce): 4.512371, true ce loss: 8.091934
# ... step 80/3000, distillation loss (kl+ce): 4.305421, true ce loss: 7.728309
# ... step 90/3000, distillation loss (kl+ce): 4.041259, true ce loss: 7.246254
# ... step 100/3000, distillation loss (kl+ce): 3.820129, true ce loss: 6.848437
# ... step 110/3000, distillation loss (kl+ce): 3.623273, true ce loss: 6.499963
# ... step 120/3000, distillation loss (kl+ce): 3.391802, true ce loss: 6.081400
# ... step 130/3000, distillation loss (kl+ce): 3.200699, true ce loss: 5.740082
# ... step 140/3000, distillation loss (kl+ce): 2.976091, true ce loss: 5.328291
# ... step 150/3000, distillation loss (kl+ce): 2.792794, true ce loss: 4.995811
# ... step 160/3000, distillation loss (kl+ce): 2.610717, true ce loss: 4.663285
# ... step 170/3000, distillation loss (kl+ce): 2.424346, true ce loss: 4.318029
# ... step 180/3000, distillation loss (kl+ce): 2.240977, true ce loss: 3.974998
# ... step 190/3000, distillation loss (kl+ce): 2.024897, true ce loss: 3.565206
# ... step 200/3000, distillation loss (kl+ce): 1.882390, true ce loss: 3.294104
# ... step 210/3000, distillation loss (kl+ce): 1.692734, true ce loss: 2.933955
# ... step 220/3000, distillation loss (kl+ce): 1.584192, true ce loss: 2.726650
# ... step 230/3000, distillation loss (kl+ce): 1.465907, true ce loss: 2.500992
# ... step 240/3000, distillation loss (kl+ce): 1.326603, true ce loss: 2.231240
# ... step 250/3000, distillation loss (kl+ce): 1.235111, true ce loss: 2.050110
# ... step 260/3000, distillation loss (kl+ce): 1.143084, true ce loss: 1.880798
# ... step 270/3000, distillation loss (kl+ce): 1.064977, true ce loss: 1.733313
# ... step 280/3000, distillation loss (kl+ce): 1.012234, true ce loss: 1.640355
# ... step 290/3000, distillation loss (kl+ce): 0.968103, true ce loss: 1.557039
# ... step 300/3000, distillation loss (kl+ce): 0.931643, true ce loss: 1.493574
# ... step 310/3000, distillation loss (kl+ce): 0.872510, true ce loss: 1.381524
# ... step 320/3000, distillation loss (kl+ce): 0.836649, true ce loss: 1.320607
# ... step 330/3000, distillation loss (kl+ce): 0.796623, true ce loss: 1.250251
# ... step 340/3000, distillation loss (kl+ce): 0.724761, true ce loss: 1.118181
# ... step 350/3000, distillation loss (kl+ce): 0.720534, true ce loss: 1.118356
# ... step 360/3000, distillation loss (kl+ce): 0.672370, true ce loss: 1.031335
# ... step 370/3000, distillation loss (kl+ce): 0.659153, true ce loss: 1.014591
# ... step 380/3000, distillation loss (kl+ce): 0.632749, true ce loss: 0.966423
# ... step 390/3000, distillation loss (kl+ce): 0.631848, true ce loss: 0.975639
# ... step 400/3000, distillation loss (kl+ce): 0.624867, true ce loss: 0.969331
# ... step 410/3000, distillation loss (kl+ce): 0.558973, true ce loss: 0.843080
# ... step 420/3000, distillation loss (kl+ce): 0.585306, true ce loss: 0.905425
# ... step 430/3000, distillation loss (kl+ce): 0.586424, true ce loss: 0.913079
# ... step 440/3000, distillation loss (kl+ce): 0.525212, true ce loss: 0.796339
# ... step 450/3000, distillation loss (kl+ce): 0.523918, true ce loss: 0.800437
# ... step 460/3000, distillation loss (kl+ce): 0.527858, true ce loss: 0.815301
# ... step 470/3000, distillation loss (kl+ce): 0.539065, true ce loss: 0.843209
# ... step 480/3000, distillation loss (kl+ce): 0.494583, true ce loss: 0.759256
# ... step 490/3000, distillation loss (kl+ce): 0.506818, true ce loss: 0.790362
# ... step 500/3000, distillation loss (kl+ce): 0.489694, true ce loss: 0.761873
# ... step 510/3000, distillation loss (kl+ce): 0.474442, true ce loss: 0.734940
# ... step 520/3000, distillation loss (kl+ce): 0.452768, true ce loss: 0.696098
# ... step 530/3000, distillation loss (kl+ce): 0.452645, true ce loss: 0.698816
# ... step 540/3000, distillation loss (kl+ce): 0.459001, true ce loss: 0.717898
# ... step 550/3000, distillation loss (kl+ce): 0.458736, true ce loss: 0.721445
# ... step 560/3000, distillation loss (kl+ce): 0.435859, true ce loss: 0.680099
# ... step 570/3000, distillation loss (kl+ce): 0.453117, true ce loss: 0.718664
# ... step 580/3000, distillation loss (kl+ce): 0.435902, true ce loss: 0.687122
# ... step 590/3000, distillation loss (kl+ce): 0.427363, true ce loss: 0.674260
# ... step 600/3000, distillation loss (kl+ce): 0.432278, true ce loss: 0.687804
# ... step 610/3000, distillation loss (kl+ce): 0.448536, true ce loss: 0.724339
# ... step 620/3000, distillation loss (kl+ce): 0.425806, true ce loss: 0.682273
# ... step 630/3000, distillation loss (kl+ce): 0.447876, true ce loss: 0.729807
# ... step 640/3000, distillation loss (kl+ce): 0.421712, true ce loss: 0.680961
# ... step 650/3000, distillation loss (kl+ce): 0.413092, true ce loss: 0.665898
# ... step 660/3000, distillation loss (kl+ce): 0.412853, true ce loss: 0.668535
# ... step 670/3000, distillation loss (kl+ce): 0.419136, true ce loss: 0.684521
# ... step 680/3000, distillation loss (kl+ce): 0.401998, true ce loss: 0.652496
# ... step 690/3000, distillation loss (kl+ce): 0.401882, true ce loss: 0.654788
# ... step 700/3000, distillation loss (kl+ce): 0.400309, true ce loss: 0.652690
# ... step 710/3000, distillation loss (kl+ce): 0.405867, true ce loss: 0.667919
# ... step 720/3000, distillation loss (kl+ce): 0.386585, true ce loss: 0.631696
# ... step 730/3000, distillation loss (kl+ce): 0.392974, true ce loss: 0.645959
# ... step 740/3000, distillation loss (kl+ce): 0.406708, true ce loss: 0.676275
# ... step 750/3000, distillation loss (kl+ce): 0.384773, true ce loss: 0.634910
# ... step 760/3000, distillation loss (kl+ce): 0.411694, true ce loss: 0.691130
# ... step 770/3000, distillation loss (kl+ce): 0.386245, true ce loss: 0.642520
# ... step 780/3000, distillation loss (kl+ce): 0.367437, true ce loss: 0.606900
# ... step 790/3000, distillation loss (kl+ce): 0.387933, true ce loss: 0.649962
# ... step 800/3000, distillation loss (kl+ce): 0.386108, true ce loss: 0.647619
# ... step 810/3000, distillation loss (kl+ce): 0.388293, true ce loss: 0.654394
# ... step 820/3000, distillation loss (kl+ce): 0.387465, true ce loss: 0.654823
# ... step 830/3000, distillation loss (kl+ce): 0.378242, true ce loss: 0.637701
# ... step 840/3000, distillation loss (kl+ce): 0.382139, true ce loss: 0.647799
# ... step 850/3000, distillation loss (kl+ce): 0.381403, true ce loss: 0.647142
# ... step 860/3000, distillation loss (kl+ce): 0.368660, true ce loss: 0.623063
# ... step 870/3000, distillation loss (kl+ce): 0.374451, true ce loss: 0.635959
# ... early stopping triggered at step 873. no improvement in true ce loss for 100 steps.
#   distillation simulation finished.
#
# ... training 4. LongFormer (runs distillation) ...
# ... step 10/3000, distillation loss (kl+ce): 6.258193, true ce loss: 11.009715
# ... step 20/3000, distillation loss (kl+ce): 6.000753, true ce loss: 10.615244
# ... step 30/3000, distillation loss (kl+ce): 5.773381, true ce loss: 10.272394
# ... step 40/3000, distillation loss (kl+ce): 5.514158, true ce loss: 9.850260
# ... step 50/3000, distillation loss (kl+ce): 5.285770, true ce loss: 9.474980
# ... step 60/3000, distillation loss (kl+ce): 5.061235, true ce loss: 9.105448
# ... step 70/3000, distillation loss (kl+ce): 4.817868, true ce loss: 8.686417
# ... step 80/3000, distillation loss (kl+ce): 4.582401, true ce loss: 8.278625
# ... step 90/3000, distillation loss (kl+ce): 4.352584, true ce loss: 7.879843
# ... step 100/3000, distillation loss (kl+ce): 4.102232, true ce loss: 7.432156
# ... step 110/3000, distillation loss (kl+ce): 3.886952, true ce loss: 7.056053
# ... step 120/3000, distillation loss (kl+ce): 3.663115, true ce loss: 6.657871
# ... step 130/3000, distillation loss (kl+ce): 3.457533, true ce loss: 6.292322
# ... step 140/3000, distillation loss (kl+ce): 3.233421, true ce loss: 5.888588
# ... step 150/3000, distillation loss (kl+ce): 2.985715, true ce loss: 5.434273
# ... step 160/3000, distillation loss (kl+ce): 2.774083, true ce loss: 5.050238
# ... step 170/3000, distillation loss (kl+ce): 2.500074, true ce loss: 4.536634
# ... step 180/3000, distillation loss (kl+ce): 2.264758, true ce loss: 4.098913
# ... step 190/3000, distillation loss (kl+ce): 2.038075, true ce loss: 3.674570
# ... step 200/3000, distillation loss (kl+ce): 1.834961, true ce loss: 3.294221
# ... step 210/3000, distillation loss (kl+ce): 1.620708, true ce loss: 2.892499
# ... step 220/3000, distillation loss (kl+ce): 1.427909, true ce loss: 2.530043
# ... step 230/3000, distillation loss (kl+ce): 1.285821, true ce loss: 2.266866
# ... step 240/3000, distillation loss (kl+ce): 1.100900, true ce loss: 1.917527
# ... step 250/3000, distillation loss (kl+ce): 0.997587, true ce loss: 1.727244
# ... step 260/3000, distillation loss (kl+ce): 0.896089, true ce loss: 1.541142
# ... step 270/3000, distillation loss (kl+ce): 0.794694, true ce loss: 1.353767
# ... step 280/3000, distillation loss (kl+ce): 0.732164, true ce loss: 1.241151
# ... step 290/3000, distillation loss (kl+ce): 0.663280, true ce loss: 1.115141
# ... step 300/3000, distillation loss (kl+ce): 0.618645, true ce loss: 1.036901
# ... step 310/3000, distillation loss (kl+ce): 0.596123, true ce loss: 1.001142
# ... step 320/3000, distillation loss (kl+ce): 0.542743, true ce loss: 0.902387
# ... step 330/3000, distillation loss (kl+ce): 0.509941, true ce loss: 0.845383
# ... step 340/3000, distillation loss (kl+ce): 0.518656, true ce loss: 0.869808
# ... step 350/3000, distillation loss (kl+ce): 0.473596, true ce loss: 0.785803
# ... step 360/3000, distillation loss (kl+ce): 0.422764, true ce loss: 0.689513
# ... step 370/3000, distillation loss (kl+ce): 0.450106, true ce loss: 0.748794
# ... step 380/3000, distillation loss (kl+ce): 0.442788, true ce loss: 0.738664
# ... step 390/3000, distillation loss (kl+ce): 0.440008, true ce loss: 0.737711
# ... step 400/3000, distillation loss (kl+ce): 0.412914, true ce loss: 0.687446
# ... step 410/3000, distillation loss (kl+ce): 0.395719, true ce loss: 0.655566
# ... step 420/3000, distillation loss (kl+ce): 0.430651, true ce loss: 0.728741
# ... step 430/3000, distillation loss (kl+ce): 0.439936, true ce loss: 0.751472
# ... step 440/3000, distillation loss (kl+ce): 0.419307, true ce loss: 0.712625
# ... step 450/3000, distillation loss (kl+ce): 0.390793, true ce loss: 0.658696
# ... step 460/3000, distillation loss (kl+ce): 0.374324, true ce loss: 0.627843
# ... step 470/3000, distillation loss (kl+ce): 0.359418, true ce loss: 0.600469
# ... step 480/3000, distillation loss (kl+ce): 0.371730, true ce loss: 0.627308
# ... step 490/3000, distillation loss (kl+ce): 0.376931, true ce loss: 0.639246
# ... step 500/3000, distillation loss (kl+ce): 0.371888, true ce loss: 0.631347
# ... step 510/3000, distillation loss (kl+ce): 0.366274, true ce loss: 0.621902
# ... step 520/3000, distillation loss (kl+ce): 0.379865, true ce loss: 0.650880
# ... step 530/3000, distillation loss (kl+ce): 0.360321, true ce loss: 0.613683
# ... step 540/3000, distillation loss (kl+ce): 0.370801, true ce loss: 0.635960
# ... step 550/3000, distillation loss (kl+ce): 0.365525, true ce loss: 0.627173
# ... step 560/3000, distillation loss (kl+ce): 0.366616, true ce loss: 0.629908
# ... step 570/3000, distillation loss (kl+ce): 0.374491, true ce loss: 0.647110
# ... step 580/3000, distillation loss (kl+ce): 0.366222, true ce loss: 0.632490
# ... step 590/3000, distillation loss (kl+ce): 0.363464, true ce loss: 0.627868
# ... step 600/3000, distillation loss (kl+ce): 0.361177, true ce loss: 0.625302
# ... step 610/3000, distillation loss (kl+ce): 0.351931, true ce loss: 0.607331
# ... step 620/3000, distillation loss (kl+ce): 0.382638, true ce loss: 0.669559
# ... early stopping triggered at step 624. no improvement in true ce loss for 100 steps.
#   distillation simulation finished.

# %%
import time
from typing import Dict

def perform_inference() -> Dict[str, Dict[str, float]]: 

    results: Dict[str, Dict[str, float]] = dict()
    
    # define loss
    final_criterion = nn.CrossEntropyLoss(ignore_index=TOKENIZER.pad_token_id, reduction='mean') 
    
    # reshape true token targets for loss calc
    Y_target_base_flat = Y_true_base[:, 1:].flatten()
    Y_target_test_flat = Y_true_test[:, 1:].flatten()

    # perform inference
    for name, model in models.items():
        # warm up runs
        for _ in range(5):
            _ = model(Q_base, K_base, V_base, Y_true_base)
        
        NUM_RUNS = 10
        
        # timing setup
        if DEVICE.type == 'cuda':
            torch.cuda.synchronize()

            start_event = torch.cuda.Event(enable_timing=True)
            end_event = torch.cuda.Event(enable_timing=True)

            start_event.record() # type: ignore
            with torch.no_grad():
                for _ in range(NUM_RUNS):
                    output_logits_base = model(Q_base, K_base, V_base, Y_true_base)
            end_event.record() # type: ignore
        
            torch.cuda.synchronize()
            avg_time = start_event.elapsed_time(end_event) / 1000 / NUM_RUNS # compute avg. time
        else:
            # fallback to cpu
            start_time = time.time()
            with torch.no_grad():
                for _ in range(NUM_RUNS):
                     output_logits_base = model(Q_base, K_base, V_base, Y_true_base)
            avg_time = (time.time() - start_time) / NUM_RUNS
        
        
        # analysis 1 - accuracy vs. sparsity / rank (approximation quality)
        output_logits_base_flat = output_logits_base.view(-1, output_logits_base.shape[-1])
        standard_output_target_logits_flat = standard_output_target_logits.view(-1, standard_output_target_logits.shape[-1])
        
        if name == '1. Standard MHA':
            # standard model's loss against true labels (ce loss)
            mse_accuracy = final_criterion(output_logits_base_flat, Y_target_base_flat).item() 
        else:
            # approximation model's loss (mse between logits of student and teacher)
            mse_accuracy = f.mse_loss(output_logits_base_flat, standard_output_target_logits_flat).item() 
            
        
        # analysis 2 - generalization (approximation on n_test)
        try:
            with torch.no_grad():
                output_logits_test = model(Q_test, K_test, V_test, Y_true_test)
            
            output_logits_test_flat = output_logits_test.view(-1, output_logits_test.shape[-1])
            standard_output_test_target_logits_flat = standard_output_test_target_logits.view(-1, standard_output_test_target_logits.shape[-1])
            
            if name == '1. Standard MHA':
                 mse_test = final_criterion(output_logits_test_flat, Y_target_test_flat).item()
                 generalization_ratio = 1.0  # as target model 
            else:
                mse_test = f.mse_loss(output_logits_test_flat, standard_output_test_target_logits_flat).item()
                if mse_accuracy > 1e-9: generalization_ratio = mse_test / mse_accuracy
                else: generalization_ratio = 1.0
            
        except RuntimeError as e:
            # generalization is allowed to fail only if seq len exceeds n_max
            if 'exceeds fixed projection size' in str(e) and name == '2. Linformer':
                print(f"  [{name}]: generalization test failed (sequence length error: {e})")
            else:
                # for performer or longformer, a runtime error is a major failure
                print(f"  [{name}]: generalization test failed (unexpected error: {e})")

            mse_test = 1000.0 
            generalization_ratio = 1000.0 
            
        print(f"[{name}]: Avg Time: {avg_time:.4f}s | Metric (Accuracy Proxy): {mse_accuracy:.6f} | Gen. Ratio: {generalization_ratio:.2f}")

        # store results
        results[name] = {
            "Practical Speed (s)": avg_time,
            "Approximation Quality (Metric)": mse_accuracy, 
            "Generalization Factor (Test Metric / Base Metric)": generalization_ratio
        }

    return results


# inference
results = perform_inference()
# Out:
# [1. Standard MHA]: Avg Time: 0.2985s | Metric (Accuracy Proxy): 11.536810 | Gen. Ratio: 1.00
#   [2. Linformer]: generalization test failed (sequence length error: ... linformer: sequence length 4096 exceeds fixed projection size 2048. failed to generalize ...)
# [2. Linformer]: Avg Time: 0.2302s | Metric (Accuracy Proxy): 13978.585938 | Gen. Ratio: 1000.00
# [3. Performer]: Avg Time: 0.2342s | Metric (Accuracy Proxy): 0.474426 | Gen. Ratio: 0.99
# [4. LongFormer]: Avg Time: 0.3222s | Metric (Accuracy Proxy): 0.379533 | Gen. Ratio: 0.94

# %%
print("--- summary of the analysis ---")
for name, metrics in results.items():
    print(f"** {name.split('. ')[1]} **:")
    print(f"  * Speed: {metrics['Practical Speed (s)']:.4f}s")
    print(f"  * Metric: {metrics['Approximation Quality (Metric)']:.6f}")
    print(f"  * Generalization Factor: {metrics['Generalization Factor (Test Metric / Base Metric)']:.2f}")
# Out:
# --- summary of the analysis ---
# ** Standard MHA **:
#   * Speed: 0.2985s
#   * Metric: 11.536810
#   * Generalization Factor: 1.00
# ** Linformer **:
#   * Speed: 0.2302s
#   * Metric: 13978.585938
#   * Generalization Factor: 1000.00
# ** Performer **:
#   * Speed: 0.2342s
#   * Metric: 0.474426
#   * Generalization Factor: 0.99
# ** LongFormer **:
#   * Speed: 0.3222s
#   * Metric: 0.379533
#   * Generalization Factor: 0.94

# %%
# plot the results

import numpy as np
import matplotlib.pyplot as plt


def plot_comparison(results: Dict[str, Dict[str, float]]) -> None:
    names_full = list(results.keys())
    accuracy = [results[name]["Approximation Quality (Metric)"] for name in names_full]
    generalization = [results[name]["Generalization Factor (Test Metric / Base Metric)"] for name in names_full]
    speed = [results[name]["Practical Speed (s)"] for name in names_full]

    x = np.arange(len(names_full)) 
    std_speed_ref = results["1. Standard MHA"]["Practical Speed (s)"]
    std_ce_loss = results["1. Standard MHA"]["Approximation Quality (Metric)"]
    clean_names = [n.split('. ')[1] for n in names_full]
        
    _, axes = plt.subplots(1, 3, figsize=(18, 6))
    plt.suptitle('Comparison of Attention Mechanisms of Seq2Seq Transformers', fontsize=16)

    ax1 = axes[0]
    colors1 = ['darkred'] + ['skyblue'] * (len(x) - 1)
    ax1.set_ylim(bottom=0.0, top=15)
    ax1.set_ylabel('Loss (Standard: True CE Loss, Approx: Logit MSE)', color='black')
    ax1.set_title('Approximation Quality vs Standard MHA', pad=15)
    ax1.set_xticks(x)
    ax1.set_xticklabels(clean_names, rotation=90, ha="right")
    ax1.grid(axis='y', linestyle='--', alpha=0.7)
    bars1 = ax1.bar(x, accuracy, width=0.5, color=colors1)
    for i, bar in enumerate(bars1):
        height = bar.get_height()
        ax1.annotate(f'{height:.2e}' if i > 0 else f'{height:.4f}', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3),    textcoords="offset points",  ha='center', va='bottom')

    ax2 = axes[1]
    colors2 = ['darkred'] + ['mediumseagreen'] * (len(x) - 1)
    ax2.set_ylim(bottom=0.5, top=2.0)
    ax2.set_ylabel('Test Metric / Base Metric Ratio', color='black')
    ax2.set_title(f'Generalization ($N_{{test}}={N_TEST:,}$ vs $N_{{base}}={N:,}$)', pad=15)
    ax2.set_xticks(x)
    ax2.set_xticklabels(clean_names, rotation=90, ha="right")
    ax2.grid(axis='y', linestyle='--', alpha=0.7)
    bars2 = ax2.bar(x, generalization, width=0.5, color=colors2)
    for bar in bars2:
        height = bar.get_height()
        ax2.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

    ax3 = axes[2]
    colors3 = ['darkred'] + ['lightcoral'] * (len(x) - 1)
    ax3.set_ylim(bottom=0.2, top=0.35)
    ax3.set_ylabel('Time (seconds)', color='black')
    ax3.set_title(f'Practical Training Speed (N={N:,})', pad=15)
    ax3.set_xticks(x)
    ax3.set_xticklabels(clean_names, rotation=90, ha="right")
    ax3.grid(axis='y', linestyle='--', alpha=0.7)
    bars3 = ax3.bar(x, speed, width=0.5, color=colors3)
    for bar in bars3:
        height = bar.get_height()
        ax3.annotate(f'{height:.4f}', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # type: ignore
    plt.show()

plot_comparison(results)
